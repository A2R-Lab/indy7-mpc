# %%
import os
import sys
sys.path.append('./src')
sys.path.append('../../') # to get bindings
#sys.path.append('./dependencies/indy-ros2/indy_description/urdf_files')

from utils import *
#from gato_mpc import *
from gato_mpc_batch_sample import *
import pinocchio as pin
from pinocchio.visualize import MeshcatVisualizer
import meshcat.geometry as g
import meshcat.transformations as tf
import numpy as np
np.set_printoptions(linewidth=99999999)

# Load robot model
model_dir = "description/"
urdf_path = model_dir + "indy7.urdf"
model, visual_model, collision_model = load_robot_model(urdf_path, model_dir)

# Create MPC solver and optimizer
#controller = MPC_GATO(model, N=32, dt=0.01)
f_ext = np.array([5.0, 0.0, 15, 0.0, 0.0, 0.0])
controller_sample = MPC_GATO_Batch_Sample(model, N=32, dt=0.01, batch_size=64, 
                                   constant_f_ext=f_ext, resample_f_ext=True, 
                                   f_ext_std=5, f_ext_resample_std=0.2)

controller = MPC_GATO_Batch_Sample(model, N=32, dt=0.01, batch_size=1, 
                                   constant_f_ext=f_ext, resample_f_ext=False, 
                                   f_ext_std=0.0, f_ext_resample_std=0.0)
# Out:
# f_ext_batch:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-7.21007130e-01  1.29430919e+00  1.77818747e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.72814645e+00  8.22848283e+00  2.85989632e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.18256287e+00  2.57310683e+00 -4.72147858e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.36362441e+00 -7.41504027e+00  1.81055098e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.20732342e-01 -6.87420506e+00 -2.80143606e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.45084653e+00 -9.87853090e+00 -1.73656230e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.99458418e+00 -2.34314440e+00  3.62241714e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 5.45059317e+00  1.99872973e+00 -5.18486233e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.29187870e+00 -5.09356686e+00  2.52535968e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.22124929e+00  4.42984805e+00 -1.01481696e+01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.95047646e+00  3.49105505e+00  2.97210457e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 3.95488611e+00 -5.21763629e-01 -4.26092145e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-6.20362258e+00  3.43367401e+00  1.71805711e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 3.18821032e+00  1.28903708e+00 -8.37245834e-03  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.87344845e+00  1.74302805e-01  3.94411024e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 6.53966629e+00 -2.44016100e+00  7.34568743e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.14253705e+00  2.34012734e-01 -2.16395896e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.34874188e+00  1.78162575e+00 -1.89379998e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.91307210e+00  9.47716717e+00 -2.32427463e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 5.82745654e+00  1.35365012e+00 -4.28865950e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.54641218e+00 -8.06945411e+00  8.86953542e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.18023881e+00 -4.12242441e+00 -2.62688219e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-5.44726182e+00  1.40232748e+00 -1.98105793e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-7.14469429e+00 -2.48734157e+00  2.20295859e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.44899323e+00  1.79161122e+00  1.65842471e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.41057640e+00 -4.72636894e+00 -2.73514673e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-2.22534722e+00  6.23046684e+00  5.81739889e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 3.47393043e+00  7.83231158e+00 -4.36332557e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-2.96655071e+00 -1.48465854e+00  4.07354603e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-7.84258815e+00 -1.12517649e+01 -8.65731441e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.16467675e+00  1.18016623e+00  4.30951758e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.24007702e+00 -4.30366687e+00  2.31573679e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.64202744e+00 -7.20992263e+00 -3.19305024e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.92999117e+00  4.78834417e+00  2.10707333e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.78847749e+00 -1.83490379e+00 -5.86511076e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 5.54018546e+00  4.04547415e+00  7.02712837e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.30726363e+00  5.96544668e+00 -3.41830799e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-2.73473430e+00 -1.64880372e+00 -1.70162939e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-6.45815961e+00 -2.08343281e+00  1.20761568e+01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.94383534e+00  1.55001852e+00 -1.39392325e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 6.11482649e-01  5.71219211e+00  4.51657497e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-4.61933527e-01  9.28174839e+00  2.31742935e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-7.95252394e+00  1.68309582e+00 -8.62176407e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.18169390e+00 -3.42809289e+00  5.51612571e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.02042708e+00  1.05034597e+01  5.57980459e-02  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.68007999e-01 -6.34928673e+00  4.50481757e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-8.81546490e+00  9.82417140e-04 -4.10628842e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-2.69927904e+00 -1.04535612e+01  4.32440172e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.78110913e+00  3.65266670e-01  4.37921962e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.00288027e+00 -2.46241012e-01  7.30244686e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 3.27045144e+00  1.55477274e+00 -7.28090937e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.25361657e+00  1.88064944e+00 -4.57255758e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 9.52181092e-02 -1.03497275e+01 -8.59366378e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 3.03393002e+00  6.91317549e+00 -1.60960460e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.43798168e-01 -1.25183354e+00  7.63105876e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.79348166e+00  1.61673938e+00 -8.13469062e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 8.38310667e-01 -6.81391224e+00 -5.17741624e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-7.84922996e-01  5.22182840e+00  2.09085250e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-4.12828934e+00 -2.85714510e+00 -3.68357366e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.98399387e+00 -5.26143018e+00 -6.33719457e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 6.36478830e+00 -7.77261400e+00  4.41903392e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 5.24676482e+00 -6.22989626e-01 -4.18305331e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.83127359e+00  2.98006824e+00 -8.86430074e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# f_ext_batch:
# [[0. 0. 0. 0. 0. 0.]]

# %%
# initial state
#xstart = np.zeros(controller.nx)
xstart = np.hstack((np.zeros(controller.nq), np.zeros(controller.nv)))

# goal ee positions
endpoints = np.array([
    np.array(controller.eepos(np.array([0.34848965, 0.3, 0.84213701, 0.0, 0.0, 0.0]))),
    np.array(controller.eepos(1.6*np.ones(controller.nq))),
    np.array(controller.eepos(0.5*np.ones(controller.nq))),
    #np.array(controller.eepos(np.zeros(controller.nq))),
    np.array(controller.eepos(0.2*np.ones(controller.nq))),
    #np.array(controller.eepos(np.zeros(controller.nq))), 
    #np.array(controller.eepos(np.array([-3.0, 1.0, 1.0, 1.0, 0.0, 0.0]))),
    np.array(controller.eepos(-0.5*np.ones(controller.nq))),
    #np.array(controller.eepos(np.zeros(controller.nq))),
    np.array(controller.eepos(-0.9*np.ones(controller.nq))),
    #np.array(controller.eepos(np.zeros(controller.nq))),
    np.array(controller.eepos(0.5*np.ones(controller.nq))),
    np.array(controller.eepos(np.array([0.5, 1.5, 2.0, 0.0, 0.0, 0.0]))),
    
])

# %%
# Run MPC
q_trajectory_sample, mpc_stats_sample = controller_sample.run_mpc(xstart, endpoints, 0.005, 10)
# Out:
# Running MPC with 2000 steps, sim_dt: 0.005
# Endpoints:
# [[ 0.18396349 -0.61205797 -0.06910995]
#  [-0.45139566 -0.47758791  0.977525  ]
#  [-0.24310366 -0.24261648  1.21597466]
#  [ 0.45139566 -0.47758791  0.977525  ]
#  [ 0.33030096 -0.77069748  0.53591299]
#  [-0.45139566 -0.47758791  0.977525  ]
#  [-0.14504827 -0.29175585 -0.15375282]]
# (64, 12)
# (64, 192)
# (64, 570)
# t:    0.000, goal dist:  1.41473, best_id: 0
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# t:    0.050, goal dist:  1.41412, best_id: 16
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# t:    0.100, goal dist:  1.41193, best_id: 15
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# t:    0.200, goal dist:  1.15216, best_id: 37
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# t:    0.350, goal dist:  0.22158, best_id: 3
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# (64, 12)
# (64, 192)
# (64, 570)
# t:    0.400, goal dist:  0.12319, best_id: 31
# (64, 12)
# (64, 192)
# (64, 570)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Run MPC
# ----> 2 q_trajectory_sample, mpc_stats_sample = controller_sample.run_mpc(xstart, endpoints, 0.005, 10)
#
# File ~/alex/GATO/examples/indy7-mpc/./src/gato_mpc_batch_sample.py:235, in MPC_GATO_Batch_Sample.run_mpc(self, xstart, endpoints, sim_dt, sim_time)
#     232 end_time = time.time()
#     234 # find best traj after simulation step (most closely matched dynamics)
# --> 235 best_id = self.find_best_trajectory_id(x_last, u_last, xcur, sim_dt)
#     236 XU_best = XU_batch_new[best_id, :]
#     237 # -----
#     238
#     239 # print every 0.05 seconds
#
# File ~/alex/GATO/examples/indy7-mpc/./src/gato_mpc_batch_sample.py:288, in MPC_GATO_Batch_Sample.find_best_trajectory_id(self, x_last, u_last, xcur, dt)
#     285 # Add the transformed force to the last joint
#     286 forces.append(local_force)
# --> 288 q, v = rk4(model, data, x_last[:self.nq], x_last[self.nq:self.nx], u_last, dt, forces)
#     289 x_next = np.hstack([q, v])
#     290 error = np.linalg.norm(x_next - xcur)
#
# File ~/alex/GATO/examples/indy7-mpc/./src/utils.py:17, in rk4(model, data, q, v, u, dt, f_ext)
#      15 v_next = v + (dt/6) * (k1v + 2*k2v + 2*k3v + k4v)
#      16 avg_v = (k1q + 2*k2q + 2*k3q + k4q) / 6
# ---> 17 q_next = pin.integrate(model, q, avg_v * dt)
#      18 return q_next, v_next
#
# KeyboardInterrupt:

# %%
# Run MPC
q_trajectory, mpc_stats = controller.run_mpc(xstart, endpoints, 0.005, 10)
# Out:
# (192,)
# Running MPC with 2000 steps, sim_dt: 0.005
# Endpoints:
# [[-0.50411789 -0.3815826   0.94470905]
#  [ 0.18396349 -0.61205797 -0.06910995]
#  [-0.45139566 -0.47758791  0.977525  ]
#  [-0.24310366 -0.24261648  1.21597466]
#  [ 0.45139566 -0.47758791  0.977525  ]
#  [ 0.33030096 -0.77069748  0.53591299]
#  [-0.45139566 -0.47758791  0.977525  ]
#  [-0.14504827 -0.29175585 -0.15375282]]
# t:    0.000, goal dist:  0.62962, best_id: 0
# t:    0.050, goal dist:  0.63199, best_id: 0
# t:    0.100, goal dist:  0.63696, best_id: 0
# t:    0.200, goal dist:  0.65380, best_id: 0
# t:    0.350, goal dist:  0.70109, best_id: 0
# t:    0.400, goal dist:  0.72379, best_id: 0
# t:    0.550, goal dist:  0.82276, best_id: 0
# t:    0.700, goal dist:  0.97987, best_id: 0
# t:    0.800, goal dist:  1.12142, best_id: 0
# t:    0.950, goal dist:  0.92574, best_id: 0
# t:    1.100, goal dist:  0.41537, best_id: 0
# t:    1.150, goal dist:  0.22589, best_id: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Run MPC
# ----> 2 q_trajectory, mpc_stats = controller.run_mpc(xstart, endpoints, 0.005, 10)
#
# File ~/alex/GATO/examples/indy7-mpc/./src/gato_mpc_batch_sample.py:229, in MPC_GATO_Batch_Sample.run_mpc(self, xstart, endpoints, sim_dt, sim_time)
#     226 #self.solver.solver.resetLambda()
#     228 start_time = time.time()
# --> 229 XU_batch_new = self.solver.solve(xcur_batch, eepos_goal_batch, XU_batch)
#     230 end_time = time.time()
#     232 # find best traj after simulation step (most closely matched dynamics)
#
# File ~/alex/GATO/examples/indy7-mpc/./src/gato_mpc_batch_sample.py:57, in GATO_Batch_Sample.solve(self, xcur_batch, eepos_goals_batch, XU_batch)
#      52 def solve(self, xcur_batch, eepos_goals_batch, XU_batch):
#      53     # xcur_batch: (batch_size, state_size)
#      54     # eepos_goals_batch: (batch_size, N * 3)
#      55     # XU_batch: (batch_size, N*(state_size+control_size)-control_size)
# ---> 57     result = self.solver.solve(XU_batch, self.dt, xcur_batch, eepos_goals_batch)
#      59     XU_batch = result["xu_trajectory"]
#      60     self.stats['solve_time']['values'].append(result["solve_time_us"])
#
# KeyboardInterrupt:

# %%
for key in mpc_stats:
    print(key)
    print(mpc_stats[key])

# %%
stats = controller.solver.get_stats()
for key in stats:
    print(key)
    print(stats[key])

# %%
import matplotlib.pyplot as plt

# plot position error of mpc_stats_sample vs mpc_stats on same axis
fig, ax = plt.subplots()
ax.plot(mpc_stats_sample['goal_distances'], label='mpc_stats_sample')
ax.plot(mpc_stats['goal_distances'], label='mpc_stats')
ax.set_xlabel('Iteration')
ax.set_ylabel('Goal Distance')
ax.legend()
ax.grid(True)
plt.show()

# %%
stats = controller.solver.get_stats()

import matplotlib.pyplot as plt

fig, axs = plt.subplots(len(stats), 1, figsize=(5, 2*len(stats)))
if len(stats) == 1:
    axs = [axs]

for i, (key, data) in enumerate(stats.items()):
    ax = axs[i]
    if isinstance(data, dict) and 'values' in data:
        values = data['values']
        ax.plot(values, label=key)
        ax.set_title(f'{key} over iterations')
        if key == 'solve_time':
            ax.axhline(np.mean(values), color='r', linestyle='--', label=f'mean: {np.mean(values):.3f}')
            ax.text(0.02, 0.98, f'max: {np.max(values):.3f}\nmin: {np.min(values):.3f}', 
                   transform=ax.transAxes, verticalalignment='top')
    else:
        ax.plot(data, label=key)
        ax.set_title(f'{key} over iterations')
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# Setup pinocchio visualizer
viz = MeshcatVisualizer(model, collision_model, visual_model)
viz.initViewer()
viz.loadViewerModel()
# Visualize goals
for i, p in enumerate(endpoints):
    viz.viewer[f'point{i}'].set_object(
        g.Sphere(0.06), 
        g.MeshLambertMaterial(color=0xff0000))

    T = tf.translation_matrix(np.array(p[:]))
    viz.viewer[f'point{i}'].set_transform(T)
#print_stats(controller.solver.get_stats())
while 1:
    #viz.play(q_trajectory=q_trajectory_sample, dt=0.01)
    viz.play(q_trajectory=q_trajectory_sample, dt=0.01)
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7016/static/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 16
#      13 #print_stats(controller.solver.get_stats())
#      14 while 1:
#      15     #viz.play(q_trajectory=q_trajectory_sample, dt=0.01)
# ---> 16     viz.play(q_trajectory=q_trajectory_sample, dt=0.01)
#
# File ~/alex/GATO/examples/indy7-mpc/.venv/lib/python3.10/site-packages/cmeel.prefix/lib/python3.10/site-packages/pinocchio/visualize/base_visualizer.py:180, in BaseVisualizer.play(self, q_trajectory, dt, callback, capture, **kwargs)
#     178     elapsed_time = t1 - t0
#     179     if dt is not None and elapsed_time < dt:
# --> 180         self.sleep(dt - elapsed_time)
#     181 if capture and not self.has_video_writer():
#     182     return imgs
#
# File ~/alex/GATO/examples/indy7-mpc/.venv/lib/python3.10/site-packages/cmeel.prefix/lib/python3.10/site-packages/pinocchio/visualize/base_visualizer.py:151, in BaseVisualizer.sleep(self, dt)
#     150 def sleep(self, dt):
# --> 151     time.sleep(dt)
#
# KeyboardInterrupt:

# %%
import pickle

print(q_trajectory)

# save trajectory to file
with open('q_trajectory.pkl', 'wb') as f:
    pickle.dump(q_trajectory, f)

# %%
ee_pos = np.load('eepos_g_batch.npy')
print(ee_pos)
# Out:
# [[0.34848965 0.3        0.84213701 0.         0.         0.         0.35093436 0.3        0.8368105  0.         0.         0.         0.35332343 0.3        0.8312704  0.         0.         0.         0.35565649 0.3        0.82552023 0.         0.         0.         0.35793316 0.3        0.81956363 0.         0.         0.         0.36015308 0.3        0.81340437 0.         0.         0.         0.3623159  0.3        0.80704637 0.         0.         0.         0.36442128 0.3        0.80049365 0.         0.         0.         0.36646888 0.3        0.79375037 0.         0.         0.         0.36845837 0.3        0.78682081 0.         0.         0.         0.37038945 0.3        0.77970936 0.         0.         0.         0.37226181 0.3        0.77242053 0.         0.         0.         0.37407515 0.3        0.76495894 0.         0.         0.         0.37582917 0.3        0.75732933 0.         0.         0.         0.37752362 0.3        0.74953653 0.         0.         0.         0.37915821 0.3        0.74158549 0.         0.         0.         0.38073268 0.3        0.73348124 0.         0.         0.         0.38224679 0.3        0.72522893 0.         0.         0.         0.3837003  0.3        0.71683379 0.         0.         0.         0.38509297 0.3        0.70830114 0.         0.         0.         0.38642459 0.3        0.6996364  0.         0.         0.         0.38769495 0.3        0.69084506 0.         0.         0.         0.38890383 0.3        0.68193269 0.         0.         0.         0.39005106 0.3        0.67290495 0.         0.         0.         0.39113645 0.3        0.66376756 0.         0.         0.         0.39215982 0.3        0.65452632 0.         0.         0.         0.39312102 0.3        0.64518708 0.         0.         0.         0.39401989 0.3        0.63575577 0.         0.         0.         0.3948563  0.3        0.62623837 0.         0.         0.         0.39563009 0.3        0.61664092 0.         0.         0.         0.39634117 0.3        0.6069695  0.         0.         0.         0.39698941 0.3        0.59723024 0.         0.         0.        ]]
